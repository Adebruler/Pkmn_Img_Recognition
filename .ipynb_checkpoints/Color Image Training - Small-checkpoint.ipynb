# %%
from keras.models import Sequential
from keras_preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers, optimizers
import pandas as pd
import numpy as np
# Out:
# C:\Users\OW93790\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Read in DataFrame of stored images and types
pokedex_df=pd.read_csv("Data/Pokedex.csv").drop(labels="Unnamed: 0",axis=1)
# Convert "Type" column (read in as strings) back to lists
pokedex_df.Type=pokedex_df.Type.str[1:-1].str.split(', ').tolist()
pokedex_df.head()
# Out:
#    Nat_Dex        Name                 Type              Files
# 0        1   Bulbasaur  ['Grass', 'Poison']   001Bulbasaur.png
# 1        2     Ivysaur  ['Grass', 'Poison']     002Ivysaur.png
# 2        3    Venusaur  ['Grass', 'Poison']    003Venusaur.png
# 3        4  Charmander             ['Fire']  004Charmander.png
# 4        5  Charmeleon             ['Fire']  005Charmeleon.png

# %%
# Generate the trainer from the images and types using Keras
# Validation split chosen so that the datagens are not prime numbers and may be run in reasonable batches
datagen=ImageDataGenerator(rescale=1./255,validation_split=204/809)

# Set shuffle to false for training set. Reduce image size to reduce model storage size for gitlab
train_generator=datagen.flow_from_dataframe(dataframe=pokedex_df, directory="Images", x_col="Files", y_col="Type", subset="training", class_mode="categorical", target_size=(200,200), seed=42, batch_size=6, shuffle=False)

valid_generator=datagen.flow_from_dataframe(dataframe=pokedex_df, directory="Images", x_col="Files", y_col="Type", subset="validation", class_mode="categorical", target_size=(200,200), seed = 42, batch_size=7, shuffle=True)
# Out:
# Found 606 images belonging to 18 classes.
# Found 203 images belonging to 18 classes.

# %%
# Check logic of the classes
train_generator.classes
# Looks good. 18 classes--one for each type.
# Classes are keyed alphabetically, each pokemon has one or both of its types in original order
# Out:
# [[0],
#  [0, 16],
#  [12],
#  [10, 7],
#  [16, 10],
#  [4],
#  [4],
#  [17, 13],
#  [0, 16],
#  [0, 15],
#  [0, 5],
#  [1, 11],
#  [12],
#  [12],
#  [6],
#  [6, 15],
#  [11, 10],
#  [11, 10],
#  [17, 15],
#  [17],
#  [17],
#  [11, 7],
#  [17, 7],
#  [16, 7],
#  [1, 6],
#  [1, 6],
#  [17, 2],
#  [10],
#  [10],
#  [12],
#  [12],
#  [12],
#  [5],
#  [5],
#  [11, 14],
#  [3],
#  [6],
#  [12],
#  [12],
#  [3],
#  [6],
#  [17],
#  [15, 10],
#  [15, 10],
#  [15, 1],
#  [14, 7],
#  [6, 7],
#  [14, 9],
#  [9],
#  [9],
#  [9],
#  [6],
#  [6, 5],
#  [6, 5],
#  [17],
#  [17, 10],
#  [17, 10],
#  [1],
#  [1],
#  [12],
#  [12],
#  [0],
#  [0],
#  [0, 7],
#  [0],
#  [0, 13],
#  [17, 9],
#  [17, 9],
#  [17, 9],
#  [9],
#  [9, 1],
#  [9, 1],
#  [12, 7],
#  [12, 7],
#  [17, 7],
#  [17, 7],
#  [14, 4],
#  [14, 4],
#  [14, 4],
#  [0, 17],
#  [0, 7],
#  [9],
#  [9, 5],
#  [12],
#  [12],
#  [12],
#  [0, 10],
#  [0, 7],
#  [0, 8],
#  [12],
#  [12],
#  [12],
#  [5],
#  [5],
#  [12, 4],
#  [15],
#  [12],
# ...

# %%
# Model setting code from https://medium.com/@vijayabhaskar96/tutorial-on-keras-flow-from-dataframe-1fd4493d237c
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=(200,200,3)))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
# Reduced number of nodes to reduce overtraining
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(18, activation='softmax'))
model.compile(optimizers.rmsprop(lr=0.0001, decay=1e-6),loss="categorical_crossentropy",metrics=["accuracy"])

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
# STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=2
)
# Out:
# Epoch 1/2
# 101/101 [==============================] - 360s 4s/step - loss: 4.4092 - acc: 0.0759 - val_loss: 4.1750 - val_acc: 0.0788
# Epoch 2/2
# 101/101 [==============================] - 386s 4s/step - loss: 4.3607 - acc: 0.0858 - val_loss: 4.1658 - val_acc: 0.0788

# %%
 # Save the model
model.save("Models/Small/pkmn_model_small1.h5")

# %%
# STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=2
)
# Out:
# Epoch 1/2
# 101/101 [==============================] - 314s 3s/step - loss: 4.3089 - acc: 0.1007 - val_loss: 4.1470 - val_acc: 0.1232
# Epoch 2/2
# 101/101 [==============================] - 366s 4s/step - loss: 4.2605 - acc: 0.1122 - val_loss: 4.0793 - val_acc: 0.1379

# %%
 # Save the model
model.save("Models/Small/pkmn_model_small2.h5")

# %%
# STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=2
)
# Out:
# Epoch 1/2
# 101/101 [==============================] - 343s 3s/step - loss: 4.1718 - acc: 0.1188 - val_loss: 4.1471 - val_acc: 0.0739
# Epoch 2/2
# 101/101 [==============================] - 295s 3s/step - loss: 4.0063 - acc: 0.1848 - val_loss: 4.1688 - val_acc: 0.1379

# %%
 # Save the model
model.save("Models/Small/pkmn_model_small3.h5")

# %%
# STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=2
)
# Out:
# Epoch 1/2
# 101/101 [==============================] - 326s 3s/step - loss: 3.8901 - acc: 0.2294 - val_loss: 4.0268 - val_acc: 0.1232
# Epoch 2/2
# 101/101 [==============================] - 337s 3s/step - loss: 3.6424 - acc: 0.2789 - val_loss: 4.0680 - val_acc: 0.0936

# %%
 # Save the model
model.save("Models/Small/pkmn_model_small4.h5")

# %%
# STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=2
)
# Out:
# Epoch 1/2
# 101/101 [==============================] - 312s 3s/step - loss: 3.4289 - acc: 0.2838 - val_loss: 4.0703 - val_acc: 0.1281
# Epoch 2/2
# 101/101 [==============================] - 344s 3s/step - loss: 3.1129 - acc: 0.3729 - val_loss: 4.2770 - val_acc: 0.1133

# %%
 # Save the model
model.save("Models/Small/pkmn_model_small5.h5")

# %%
# STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=2
)
# Out:
# Epoch 1/2
# 101/101 [==============================] - 318s 3s/step - loss: 2.9519 - acc: 0.4142 - val_loss: 4.1873 - val_acc: 0.1330
# Epoch 2/2
# 101/101 [==============================] - 333s 3s/step - loss: 2.7659 - acc: 0.4703 - val_loss: 4.3316 - val_acc: 0.1478

# %%
 # Save the model
model.save("Models/Small/pkmn_model_small6.h5")

# %%
# STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=2
)
# Out:
# Epoch 1/2
# 101/101 [==============================] - 221s 2s/step - loss: 2.6446 - acc: 0.5083 - val_loss: 4.3740 - val_acc: 0.1232
# Epoch 2/2
# 101/101 [==============================] - 200s 2s/step - loss: 2.5135 - acc: 0.5083 - val_loss: 4.4314 - val_acc: 0.1084

# %%
 # Save the model
model.save("Models/Small/pkmn_model_small7.h5")

# %%
# STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=2
)
# Out:
# Epoch 1/2
# 101/101 [==============================] - 223s 2s/step - loss: 2.4461 - acc: 0.5413 - val_loss: 4.6187 - val_acc: 0.1034
# Epoch 2/2
#  12/101 [==>...........................] - ETA: 2:46 - loss: 2.3575 - acc: 0.5139
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-c64f238357a2> in <module>()
#       4                     validation_data=valid_generator,
#       5                     validation_steps=STEP_SIZE_VALID,
# ----> 6                     epochs=2
#       7 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
# ...

# %%
 # Save the model
model.save("Models/Small/pkmn_model_small8.h5")

# %%
# STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=2
)

# %%
 # Save the model
model.save("Models/Small/pkmn_model_small9.h5")

# %%
# STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=2
)

# %%
 # Save the model
model.save("Models/Small/pkmn_model_small10.h5")
