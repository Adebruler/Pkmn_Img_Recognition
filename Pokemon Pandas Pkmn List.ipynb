# %%
# Import Dependencies
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Data Source: BulbaPedia
url = 'https://bulbapedia.bulbagarden.net/wiki/List_of_Pokémon_by_National_Pokédex_number'

# %%
# Create soup response to find tables
pkmn_tables=[]
while len(pkmn_tables) < 1:
    response=requests.get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    pkmn_tables=soup.find_all('table')[1:8]

# %%
# Add Alolan forms to first stat table (Kanto)
kanto_df=pd.read_html(pkmn_tables[0].prettify())[0]
kanto_df[3][kanto_df[0].isnull()]='Alolan '+kanto_df[3][kanto_df[0].isnull()]
kanto_df
# Out:
#         0     1    2                3         4        5
# 0    Kdex  Ndex   MS          Pokémon      Type      NaN
# 1    #001  #001  NaN        Bulbasaur     Grass   Poison
# 2    #002  #002  NaN          Ivysaur     Grass   Poison
# 3    #003  #003  NaN         Venusaur     Grass   Poison
# 4    #004  #004  NaN       Charmander      Fire      NaN
# 5    #005  #005  NaN       Charmeleon      Fire      NaN
# 6    #006  #006  NaN        Charizard      Fire   Flying
# 7    #007  #007  NaN         Squirtle     Water      NaN
# 8    #008  #008  NaN        Wartortle     Water      NaN
# 9    #009  #009  NaN        Blastoise     Water      NaN
# 10   #010  #010  NaN         Caterpie       Bug      NaN
# 11   #011  #011  NaN          Metapod       Bug      NaN
# 12   #012  #012  NaN       Butterfree       Bug   Flying
# 13   #013  #013  NaN           Weedle       Bug   Poison
# 14   #014  #014  NaN           Kakuna       Bug   Poison
# 15   #015  #015  NaN         Beedrill       Bug   Poison
# 16   #016  #016  NaN           Pidgey    Normal   Flying
# 17   #017  #017  NaN        Pidgeotto    Normal   Flying
# 18   #018  #018  NaN          Pidgeot    Normal   Flying
# 19   #019  #019  NaN          Rattata    Normal      NaN
# 20    NaN  #019  NaN   Alolan Rattata      Dark   Normal
# 21   #020  #020  NaN         Raticate    Normal      NaN
# 22    NaN  #020  NaN  Alolan Raticate      Dark   Normal
# 23   #021  #021  NaN          Spearow    Normal   Flying
# 24   #022  #022  NaN           Fearow    Normal   Flying
# 25   #023  #023  NaN            Ekans    Poison      NaN
# 26   #024  #024  NaN            Arbok    Poison      NaN
# 27   #025  #025  NaN          Pikachu  Electric      NaN
# 28   #026  #026  NaN           Raichu  Electric      NaN
# 29    NaN  #026  NaN    Alolan Raichu  Electric  Psychic
# ..    ...   ...  ...              ...       ...      ...
# 140  #122  #122  NaN         Mr. Mime   Psychic    Fairy
# 141  #123  #123  NaN          Scyther       Bug   Flying
# 142  #124  #124  NaN             Jynx       Ice  Psychic
# 143  #125  #125  NaN       Electabuzz  Electric      NaN
# 144  #126  #126  NaN           Magmar      Fire      NaN
# 145  #127  #127  NaN           Pinsir       Bug      NaN
# 146  #128  #128  NaN           Tauros    Normal      NaN
# 147  #129  #129  NaN         Magikarp     Water      NaN
# 148  #130  #130  NaN         Gyarados     Water   Flying
# 149  #131  #131  NaN           Lapras     Water      Ice
# 150  #132  #132  NaN            Ditto    Normal      NaN
# 151  #133  #133  NaN            Eevee    Normal      NaN
# 152  #134  #134  NaN         Vaporeon     Water      NaN
# 153  #135  #135  NaN          Jolteon  Electric      NaN
# 154  #136  #136  NaN          Flareon      Fire      NaN
# 155  #137  #137  NaN          Porygon    Normal      NaN
# 156  #138  #138  NaN          Omanyte      Rock    Water
# 157  #139  #139  NaN          Omastar      Rock    Water
# 158  #140  #140  NaN           Kabuto      Rock    Water
# 159  #141  #141  NaN         Kabutops      Rock    Water
# 160  #142  #142  NaN       Aerodactyl      Rock   Flying
# 161  #143  #143  NaN          Snorlax    Normal      NaN
# 162  #144  #144  NaN         Articuno       Ice   Flying
# 163  #145  #145  NaN           Zapdos  Electric   Flying
# 164  #146  #146  NaN          Moltres      Fire   Flying
# 165  #147  #147  NaN          Dratini    Dragon      NaN
# 166  #148  #148  NaN        Dragonair    Dragon      NaN
# 167  #149  #149  NaN        Dragonite    Dragon   Flying
# 168  #150  #150  NaN           Mewtwo   Psychic      NaN
# 169  #151  #151  NaN              Mew   Psychic      NaN
#
# [170 rows x 6 columns]

# %%
# merge pkmn tables from all generations
all_pkmn_df=pd.DataFrame({})
for gen in range(0,7):
#     trim header row to enable merge
    gen_df = pd.read_html(pkmn_tables[gen].prettify())[0][1:]
    all_pkmn_df=all_pkmn_df.append(gen_df)
# reindex combined table
count=len(all_pkmn_df)
indices=[i for i in range(count)]
all_pkmn_df.index=indices

# %%
all_pkmn_df
# Out:
#         0     1    2            3         4         5
# 0    #001  #001  NaN    Bulbasaur     Grass    Poison
# 1    #002  #002  NaN      Ivysaur     Grass    Poison
# 2    #003  #003  NaN     Venusaur     Grass    Poison
# 3    #004  #004  NaN   Charmander      Fire       NaN
# 4    #005  #005  NaN   Charmeleon      Fire       NaN
# 5    #006  #006  NaN    Charizard      Fire    Flying
# 6    #007  #007  NaN     Squirtle     Water       NaN
# 7    #008  #008  NaN    Wartortle     Water       NaN
# 8    #009  #009  NaN    Blastoise     Water       NaN
# 9    #010  #010  NaN     Caterpie       Bug       NaN
# 10   #011  #011  NaN      Metapod       Bug       NaN
# 11   #012  #012  NaN   Butterfree       Bug    Flying
# 12   #013  #013  NaN       Weedle       Bug    Poison
# 13   #014  #014  NaN       Kakuna       Bug    Poison
# 14   #015  #015  NaN     Beedrill       Bug    Poison
# 15   #016  #016  NaN       Pidgey    Normal    Flying
# 16   #017  #017  NaN    Pidgeotto    Normal    Flying
# 17   #018  #018  NaN      Pidgeot    Normal    Flying
# 18   #019  #019  NaN      Rattata    Normal       NaN
# 19    NaN  #019  NaN      Rattata      Dark    Normal
# 20   #020  #020  NaN     Raticate    Normal       NaN
# 21    NaN  #020  NaN     Raticate      Dark    Normal
# 22   #021  #021  NaN      Spearow    Normal    Flying
# 23   #022  #022  NaN       Fearow    Normal    Flying
# 24   #023  #023  NaN        Ekans    Poison       NaN
# 25   #024  #024  NaN        Arbok    Poison       NaN
# 26   #025  #025  NaN      Pikachu  Electric       NaN
# 27   #026  #026  NaN       Raichu  Electric       NaN
# 28    NaN  #026  NaN       Raichu  Electric   Psychic
# 29   #027  #027  NaN    Sandshrew    Ground       NaN
# ..    ...   ...  ...          ...       ...       ...
# 826  #244  #780  NaN       Drampa    Normal    Dragon
# 827  #263  #781  NaN     Dhelmise     Ghost     Grass
# 828  #271  #782  NaN     Jangmo-o    Dragon       NaN
# 829  #272  #783  NaN     Hakamo-o    Dragon  Fighting
# 830  #273  #784  NaN      Kommo-o    Dragon  Fighting
# 831  #285  #785  NaN    Tapu Koko  Electric     Fairy
# 832  #286  #786  NaN    Tapu Lele   Psychic     Fairy
# 833  #287  #787  NaN    Tapu Bulu     Grass     Fairy
# 834  #288  #788  NaN    Tapu Fini     Water     Fairy
# 835  #289  #789  NaN       Cosmog   Psychic       NaN
# 836  #290  #790  NaN      Cosmoem   Psychic       NaN
# 837  #291  #791  NaN     Solgaleo   Psychic     Steel
# 838  #292  #792  NaN       Lunala   Psychic     Ghost
# 839  #293  #793  NaN     Nihilego      Rock    Poison
# 840  #294  #794  NaN     Buzzwole       Bug  Fighting
# 841  #295  #795  NaN    Pheromosa       Bug  Fighting
# 842  #296  #796  NaN    Xurkitree  Electric       NaN
# 843  #297  #797  NaN   Celesteela     Steel    Flying
# 844  #298  #798  NaN      Kartana     Grass     Steel
# 845  #299  #799  NaN     Guzzlord      Dark    Dragon
# 846  #300  #800  NaN     Necrozma   Psychic       NaN
# 847  #301  #801  NaN     Magearna     Steel     Fairy
# 848  #302  #802  NaN    Marshadow  Fighting     Ghost
# 849  #261  #803  NaN      Poipole    Poison       NaN
# 850  #262  #804  NaN    Naganadel    Poison    Dragon
# 851  #392  #805  NaN    Stakataka      Rock     Steel
# 852  #393  #806  NaN  Blacephalon      Fire     Ghost
# 853  #403  #807  NaN      Zeraora  Electric       NaN
# 854  #---  #808  NaN       Meltan     Steel       NaN
# 855  #---  #809  NaN     Melmetal     Steel       NaN
#
# [856 rows x 6 columns]

# %%
# drop alolans and alternate formes
all_pkmn_df = all_pkmn_df.drop_duplicates(subset=[3],keep="first").reset_index()
all_pkmn_df
# Out:
#      index     0     1    2            3         4         5
# 0        0  #001  #001  NaN    Bulbasaur     Grass    Poison
# 1        1  #002  #002  NaN      Ivysaur     Grass    Poison
# 2        2  #003  #003  NaN     Venusaur     Grass    Poison
# 3        3  #004  #004  NaN   Charmander      Fire       NaN
# 4        4  #005  #005  NaN   Charmeleon      Fire       NaN
# 5        5  #006  #006  NaN    Charizard      Fire    Flying
# 6        6  #007  #007  NaN     Squirtle     Water       NaN
# 7        7  #008  #008  NaN    Wartortle     Water       NaN
# 8        8  #009  #009  NaN    Blastoise     Water       NaN
# 9        9  #010  #010  NaN     Caterpie       Bug       NaN
# 10      10  #011  #011  NaN      Metapod       Bug       NaN
# 11      11  #012  #012  NaN   Butterfree       Bug    Flying
# 12      12  #013  #013  NaN       Weedle       Bug    Poison
# 13      13  #014  #014  NaN       Kakuna       Bug    Poison
# 14      14  #015  #015  NaN     Beedrill       Bug    Poison
# 15      15  #016  #016  NaN       Pidgey    Normal    Flying
# 16      16  #017  #017  NaN    Pidgeotto    Normal    Flying
# 17      17  #018  #018  NaN      Pidgeot    Normal    Flying
# 18      18  #019  #019  NaN      Rattata    Normal       NaN
# 19      20  #020  #020  NaN     Raticate    Normal       NaN
# 20      22  #021  #021  NaN      Spearow    Normal    Flying
# 21      23  #022  #022  NaN       Fearow    Normal    Flying
# 22      24  #023  #023  NaN        Ekans    Poison       NaN
# 23      25  #024  #024  NaN        Arbok    Poison       NaN
# 24      26  #025  #025  NaN      Pikachu  Electric       NaN
# 25      27  #026  #026  NaN       Raichu  Electric       NaN
# 26      29  #027  #027  NaN    Sandshrew    Ground       NaN
# 27      31  #028  #028  NaN    Sandslash    Ground       NaN
# 28      33  #029  #029  NaN     Nidoran♀    Poison       NaN
# 29      34  #030  #030  NaN     Nidorina    Poison       NaN
# ..     ...   ...   ...  ...          ...       ...       ...
# 779    826  #244  #780  NaN       Drampa    Normal    Dragon
# 780    827  #263  #781  NaN     Dhelmise     Ghost     Grass
# 781    828  #271  #782  NaN     Jangmo-o    Dragon       NaN
# 782    829  #272  #783  NaN     Hakamo-o    Dragon  Fighting
# 783    830  #273  #784  NaN      Kommo-o    Dragon  Fighting
# 784    831  #285  #785  NaN    Tapu Koko  Electric     Fairy
# 785    832  #286  #786  NaN    Tapu Lele   Psychic     Fairy
# 786    833  #287  #787  NaN    Tapu Bulu     Grass     Fairy
# 787    834  #288  #788  NaN    Tapu Fini     Water     Fairy
# 788    835  #289  #789  NaN       Cosmog   Psychic       NaN
# 789    836  #290  #790  NaN      Cosmoem   Psychic       NaN
# 790    837  #291  #791  NaN     Solgaleo   Psychic     Steel
# 791    838  #292  #792  NaN       Lunala   Psychic     Ghost
# 792    839  #293  #793  NaN     Nihilego      Rock    Poison
# 793    840  #294  #794  NaN     Buzzwole       Bug  Fighting
# 794    841  #295  #795  NaN    Pheromosa       Bug  Fighting
# 795    842  #296  #796  NaN    Xurkitree  Electric       NaN
# 796    843  #297  #797  NaN   Celesteela     Steel    Flying
# 797    844  #298  #798  NaN      Kartana     Grass     Steel
# 798    845  #299  #799  NaN     Guzzlord      Dark    Dragon
# 799    846  #300  #800  NaN     Necrozma   Psychic       NaN
# 800    847  #301  #801  NaN     Magearna     Steel     Fairy
# 801    848  #302  #802  NaN    Marshadow  Fighting     Ghost
# 802    849  #261  #803  NaN      Poipole    Poison       NaN
# 803    850  #262  #804  NaN    Naganadel    Poison    Dragon
# 804    851  #392  #805  NaN    Stakataka      Rock     Steel
# 805    852  #393  #806  NaN  Blacephalon      Fire     Ghost
# 806    853  #403  #807  NaN      Zeraora  Electric       NaN
# 807    854  #---  #808  NaN       Meltan     Steel       NaN
# 808    855  #---  #809  NaN     Melmetal     Steel       NaN
#
# [809 rows x 7 columns]

# %%
# Drop regional pokedex number and picture column
nat_pkmn_df=all_pkmn_df[[1,3,4,5]]
# Remove pound from national pokedex numbers
count=len(nat_pkmn_df)
for form in range(count):
    nat_pkmn_df[1][form]=nat_pkmn_df[1][form][1:]
# Rename Columns
nat_pkmn_df=nat_pkmn_df.rename(columns={1:'nat_dex',3:'name',4:'type1',5:'type2'})

nat_pkmn_df
# Out:
# C:\Users\OW93790\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     nat_dex         name     type1     type2
# 0       001    Bulbasaur     Grass    Poison
# 1       002      Ivysaur     Grass    Poison
# 2       003     Venusaur     Grass    Poison
# 3       004   Charmander      Fire       NaN
# 4       005   Charmeleon      Fire       NaN
# 5       006    Charizard      Fire    Flying
# 6       007     Squirtle     Water       NaN
# 7       008    Wartortle     Water       NaN
# 8       009    Blastoise     Water       NaN
# 9       010     Caterpie       Bug       NaN
# 10      011      Metapod       Bug       NaN
# 11      012   Butterfree       Bug    Flying
# 12      013       Weedle       Bug    Poison
# 13      014       Kakuna       Bug    Poison
# 14      015     Beedrill       Bug    Poison
# 15      016       Pidgey    Normal    Flying
# 16      017    Pidgeotto    Normal    Flying
# 17      018      Pidgeot    Normal    Flying
# 18      019      Rattata    Normal       NaN
# 19      020     Raticate    Normal       NaN
# 20      021      Spearow    Normal    Flying
# 21      022       Fearow    Normal    Flying
# 22      023        Ekans    Poison       NaN
# 23      024        Arbok    Poison       NaN
# 24      025      Pikachu  Electric       NaN
# 25      026       Raichu  Electric       NaN
# 26      027    Sandshrew    Ground       NaN
# 27      028    Sandslash    Ground       NaN
# 28      029     Nidoran♀    Poison       NaN
# 29      030     Nidorina    Poison       NaN
# ..      ...          ...       ...       ...
# 779     780       Drampa    Normal    Dragon
# 780     781     Dhelmise     Ghost     Grass
# 781     782     Jangmo-o    Dragon       NaN
# 782     783     Hakamo-o    Dragon  Fighting
# 783     784      Kommo-o    Dragon  Fighting
# 784     785    Tapu Koko  Electric     Fairy
# 785     786    Tapu Lele   Psychic     Fairy
# 786     787    Tapu Bulu     Grass     Fairy
# 787     788    Tapu Fini     Water     Fairy
# 788     789       Cosmog   Psychic       NaN
# 789     790      Cosmoem   Psychic       NaN
# 790     791     Solgaleo   Psychic     Steel
# 791     792       Lunala   Psychic     Ghost
# 792     793     Nihilego      Rock    Poison
# 793     794     Buzzwole       Bug  Fighting
# 794     795    Pheromosa       Bug  Fighting
# 795     796    Xurkitree  Electric       NaN
# 796     797   Celesteela     Steel    Flying
# 797     798      Kartana     Grass     Steel
# 798     799     Guzzlord      Dark    Dragon
# 799     800     Necrozma   Psychic       NaN
# 800     801     Magearna     Steel     Fairy
# 801     802    Marshadow  Fighting     Ghost
# 802     803      Poipole    Poison       NaN
# 803     804    Naganadel    Poison    Dragon
# 804     805    Stakataka      Rock     Steel
# 805     806  Blacephalon      Fire     Ghost
# 806     807      Zeraora  Electric       NaN
# 807     808       Meltan     Steel       NaN
# 808     809     Melmetal     Steel       NaN
#
# [809 rows x 4 columns]

# %%
# Save data to csv
nat_pkmn_df.to_csv('Output/nat_dex.csv')
